# %%
import pandas as pd
import numpy as np
import matplotlib as plt
x=pd.read_csv("/content/air_traffic_data[1].csv")
print(x)
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
x.head()
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507       Air Canada                           AC
# 4           200507       Air Canada                           AC
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3       Air Canada                           AC  International     Canada
# 4       Air Canada                           AC  International     Canada
#
#   Activity Type Code Price Category Code    Terminal Boarding Area  \
# ...

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15007 entries, 0 to 15006
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              15007 non-null  int64
#  1   Operating Airline            15007 non-null  object
#  2   Operating Airline IATA Code  14953 non-null  object
#  3   Published Airline            15007 non-null  object
#  4   Published Airline IATA Code  14953 non-null  object
#  5   GEO Summary                  15007 non-null  object
#  6   GEO Region                   15007 non-null  object
#  7   Activity Type Code           15007 non-null  object
#  8   Price Category Code          15007 non-null  object
#  9   Terminal                     15007 non-null  object
#  10  Boarding Area                15007 non-null  object
#  11  Passenger Count              15007 non-null  int64
#  12  Adjusted Activity Type Code  15007 non-null  object
# ...

# %%
x.tail()
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 15002    Virgin America                          VX       Domestic         US
# 15003    Virgin America                          VX  International     Mexico
# 15004    Virgin America                          VX  International     Mexico
# 15005   Virgin Atlantic                          VS  International     Europe
# 15006   Virgin Atlantic                          VS  International     Europe
#
#       Activity Type Code Price Category Code       Terminal Boarding Area  \
# ...

# %%
x.shape
# Out:
# (15007, 16)

# %%
x.describe()
# Out:
#        Activity Period  Passenger Count  Adjusted Passenger Count  \
# count     15007.000000     15007.000000              15007.000000
# mean     201045.073366     29240.521090              29331.917105
# std         313.336196     58319.509284              58284.182219
# min      200507.000000         1.000000                  1.000000
# 25%      200803.000000      5373.500000               5495.500000
# 50%      201011.000000      9210.000000               9354.000000
# 75%      201308.000000     21158.500000              21182.000000
# max      201603.000000    659837.000000             659837.000000
#
#                Year
# count  15007.000000
# mean    2010.385220
# std        3.137589
# min     2005.000000
# 25%     2008.000000
# 50%     2010.000000
# 75%     2013.000000
# max     2016.000000

# %%
x.isnull()
# Out:
#        Activity Period  Operating Airline  Operating Airline IATA Code  \
# 0                False              False                        False
# 1                False              False                        False
# 2                False              False                        False
# 3                False              False                        False
# 4                False              False                        False
# ...                ...                ...                          ...
# 15002            False              False                        False
# 15003            False              False                        False
# 15004            False              False                        False
# 15005            False              False                        False
# 15006            False              False                        False
#
#        Published Airline  Published Airline IATA Code  GEO Summary  \
# ...

# %%
x.isnull().sum()
# Out:
# Activity Period                 0
# Operating Airline               0
# Operating Airline IATA Code    54
# Published Airline               0
# Published Airline IATA Code    54
# GEO Summary                     0
# GEO Region                      0
# Activity Type Code              0
# Price Category Code             0
# Terminal                        0
# Boarding Area                   0
# Passenger Count                 0
# Adjusted Activity Type Code     0
# Adjusted Passenger Count        0
# Year                            0
# Month                           0
# dtype: int64

# %%
x.notnull().sum()
# Out:
# Activity Period                15007
# Operating Airline              15007
# Operating Airline IATA Code    14953
# Published Airline              15007
# Published Airline IATA Code    14953
# GEO Summary                    15007
# GEO Region                     15007
# Activity Type Code             15007
# Price Category Code            15007
# Terminal                       15007
# Boarding Area                  15007
# Passenger Count                15007
# Adjusted Activity Type Code    15007
# Adjusted Passenger Count       15007
# Year                           15007
# Month                          15007
# dtype: int64

# %%
x.dropna()
# Out:
#        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
x.head(6)
# Out:
#    Activity Period Operating Airline Operating Airline IATA Code  \
# 0           200507      ATA Airlines                          TZ
# 1           200507      ATA Airlines                          TZ
# 2           200507      ATA Airlines                          TZ
# 3           200507       Air Canada                           AC
# 4           200507       Air Canada                           AC
# 5           200507         Air China                          CA
#
#   Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# 0      ATA Airlines                          TZ       Domestic         US
# 1      ATA Airlines                          TZ       Domestic         US
# 2      ATA Airlines                          TZ       Domestic         US
# 3       Air Canada                           AC  International     Canada
# 4       Air Canada                           AC  International     Canada
# ...

# %%
x.nunique()
# Out:
# Activity Period                  129
# Operating Airline                 77
# Operating Airline IATA Code       73
# Published Airline                 68
# Published Airline IATA Code       64
# GEO Summary                        2
# GEO Region                         9
# Activity Type Code                 3
# Price Category Code                2
# Terminal                           5
# Boarding Area                      8
# Passenger Count                11699
# Adjusted Activity Type Code        3
# Adjusted Passenger Count       11702
# Year                              12
# Month                             12
# dtype: int64

# %%
x.value_counts
# Out:
# <bound method DataFrame.value_counts of        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
x.sort_values
# Out:
# <bound method DataFrame.sort_values of        Activity Period Operating Airline Operating Airline IATA Code  \
# 0               200507      ATA Airlines                          TZ
# 1               200507      ATA Airlines                          TZ
# 2               200507      ATA Airlines                          TZ
# 3               200507       Air Canada                           AC
# 4               200507       Air Canada                           AC
# ...                ...               ...                         ...
# 15002           201603    Virgin America                          VX
# 15003           201603    Virgin America                          VX
# 15004           201603    Virgin America                          VX
# 15005           201603   Virgin Atlantic                          VS
# 15006           201603   Virgin Atlantic                          VS
#
#       Published Airline Published Airline IATA Code    GEO Summary GEO Region  \
# ...

# %%
import seaborn as sns
sns.histplot(x = "Activity Period", data=x)
# Out:
# <Axes: xlabel='Activity Period', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Operating Airline", data=x)
# Out:
# <Axes: xlabel='Operating Airline', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Operating Airline IATA Code", data=x)
# Out:
# <Axes: xlabel='Operating Airline IATA Code', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Published Airline", data=x)
# Out:
# <Axes: xlabel='Published Airline', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Published Airline IATA Code", data=x)
# Out:
# <Axes: xlabel='Published Airline IATA Code', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "GEO Summary", data=x)
# Out:
# <Axes: xlabel='GEO Summary', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "GEO Region", data=x)
# Out:
# <Axes: xlabel='GEO Region', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Activity Type Code", data=x)
# Out:
# <Axes: xlabel='Activity Type Code', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Price Category Code", data=x)
# Out:
# <Axes: xlabel='Price Category Code', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Terminal", data=x)
# Out:
# <Axes: xlabel='Terminal', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Boarding Area", data=x)
# Out:
# <Axes: xlabel='Boarding Area', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Passenger Count", data=x)
# Out:
# <Axes: xlabel='Passenger Count', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Adjusted Activity Type Code", data=x)
# Out:
# <Axes: xlabel='Adjusted Activity Type Code', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Adjusted Passenger Count", data=x)
# Out:
# <Axes: xlabel='Adjusted Passenger Count', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Year", data=x)
# Out:
# <Axes: xlabel='Year', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(x = "Month", data=x)
# Out:
# <Axes: xlabel='Month', ylabel='Count'>

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Activity Period'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Passenger Count'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Adjusted Passenger Count'])

# %%
import matplotlib.pyplot as plt
def Box(x):
    plt.title("Box Plot")
    sns.boxplot(x)
    plt.show()
Box(x['Year'])

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x = x.iloc[:, 2:12]
y = x.iloc[:, 3:4]
print(x,'\n',y)
# Out:
#       GEO Region Activity Type Code Price Category Code       Terminal  \
# 0             US           Deplaned            Low Fare     Terminal 1
# 1             US           Enplaned            Low Fare     Terminal 1
# 2             US     Thru / Transit            Low Fare     Terminal 1
# 3         Canada           Deplaned               Other     Terminal 1
# 4         Canada           Enplaned               Other     Terminal 1
# ...          ...                ...                 ...            ...
# 15002         US           Enplaned            Low Fare     Terminal 2
# 15003     Mexico           Deplaned            Low Fare  International
# 15004     Mexico           Enplaned            Low Fare     Terminal 2
# 15005     Europe           Deplaned               Other  International
# 15006     Europe           Enplaned               Other  International
#
#       Boarding Area  Passenger Count
# 0                 B            27271
# 1                 B            29131
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=2)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (12005, 10)
# (12005, 1)
# (3002, 10)
# (3002, 1)

# %%
airline_codes = {
    'TZ': 1, 'AC': 2, 'CA': 3, 'AF': 4, 'NZ': 5, 'FL': 6, 'AS': 7, 'NH': 8, 'AA': 9, 'MQ': 10,
    'OZ': 11, 'EV': 12, '4T': 13, 'BA': 14, 'CX': 15, 'CI': 16, 'DL': 17, 'BR': 18, 'F9': 19,
    'HA': 20, 'QX': 21, 'FI': 22, 'DH': 23, 'JL': 24, 'KL': 25, 'KE': 26, 'LH': 27, 'YV': 28,
    'MX': 29, 'YX': 30, 'NW': 31, 'PR': 32, 'SQ': 33, 'OO': 34, 'SY': 35, 'TA': 36, 'US': 37,
    'UA': 38, 'VS': 39, 'WS': 40, 'GL': 41, 'QK': 42, 'QF': 43, 'A8': 44, 'NK': 45, 'XP': 46,
    'EZ': 47, 'AM': 48, 'B6': 49, 'XE': 50, 'WN': 51, 'VX': 52, 'EI': 53, 'G4': 54, '9W': 55,
    'BBB': 56, 'EK': 57, 'XJ': 58, 'WO': 59, 'AB': 60, 'RW': 61, 'LX': 62, 'LP': 63, 'SE': 64,
    'MU': 65, 'SK': 66, '5Y': 67, 'CP': 68, 'EY': 69, 'CZ': 70, 'TK': 71, 'CM': 72, 'AI': 73
}
X_train['Operating Airline IATA Code'] = X_train['Operating Airline IATA Code'].apply(lambda x: airline_codes.get(x, None))
X_test['Operating Airline IATA Code'] = X_test['Operating Airline IATA Code'].apply(lambda x: airline_codes.get(x, None))
X_train['Published Airline IATA Code'] = X_train['Published Airline IATA Code'].apply(lambda x: airline_codes.get(x, None))
X_test['Published Airline IATA Code'] = X_test['Published Airline IATA Code'].apply(lambda x: airline_codes.get(x, None))

# %%
airline_names = {
    'ATA Airlines': 1, 'Air Canada': 2, 'Air China': 3, 'Air France': 4, 'Air New Zealand': 5,
    'AirTran Airways': 6, 'Alaska Airlines': 7, 'All Nippon Airways': 8, 'American Airlines': 9,
    'Asiana Airlines': 10, 'Delta Air Lines': 11, 'BelAir Airlines': 12, 'British Airways': 13,
    'Cathay Pacific': 14, 'China Airlines': 15, 'EVA Airways': 16, 'Frontier Airlines': 17,
    'Hawaiian Airlines': 18, 'Icelandair': 19, 'Independence Air': 20, 'Japan Airlines': 21,
    'KLM Royal Dutch Airlines': 22, 'Korean Air Lines': 23, 'Lufthansa German Airlines': 24,
    'US Airways': 25, 'Mexicana Airlines': 26, 'Midwest Airlines': 27, 'Northwest Airlines': 28,
    'Philippine Airlines': 29, 'Singapore Airlines': 30, 'United Airlines - Pre 07/01/2013': 31,
    'Sun Country Airlines': 32, 'TACA': 33, 'United Airlines': 34, 'Virgin Atlantic': 35,
    'WestJet Airlines': 36, 'Boeing Company': 37, 'Miami Air International': 38, 'Qantas Airways': 39,
    'Ameriflight': 40, 'Spirit Airlines': 41, 'Xtra Airways': 42, 'Evergreen International Airlines': 43,
    'Aeromexico': 44, 'JetBlue Airways': 45, 'Southwest Airlines': 46, 'Virgin America': 47,
    'Aer Lingus': 48, 'Allegiant Air': 49, 'Jet Airways': 50, 'Emirates': 51, 'World Airways': 52,
    'Air Berlin': 53, 'Republic Airlines': 54, 'Servisair': 55, 'Pacific Aviation': 56,
    'Swiss International': 57, 'LAN Peru': 58, 'Swissport USA': 59, 'XL Airways France': 60,
    'China Eastern': 61, 'SAS Airlines': 62, 'Atlas Air, Inc': 63, 'Etihad Airways': 64,
    'China Southern': 65, 'Turkish Airlines': 66, 'COPA Airlines, Inc.': 67, 'Air India Limited': 68
}

# Convert the 'Published Airline' column to numbers
X_train['Published Airline'] = X_train['Published Airline'].apply(lambda x: airline_names.get(x, None))
X_test['Published Airline'] = X_test['Published Airline'].apply(lambda x: airline_names.get(x, None))

# %%
geo_regions = {
    'US': 1, 'Canada': 2, 'Asia': 3, 'Europe': 4, 'Australia / Oceania': 5,
    'Mexico': 6, 'Central America': 7, 'Middle East': 8, 'South America': 9
}

# Convert the 'GEO Region' column to numbers
X_train['GEO Region'] = X_train['GEO Region'].apply(lambda x: geo_regions.get(x, None))
X_test['GEO Region'] = X_test['GEO Region'].apply(lambda x: geo_regions.get(x, None))

# %%
activity_types = {
    'Deplaned': 1, 'Enplaned': 2, 'Thru / Transit': 3
}
X_train['Activity Type Code'] = X_train['Activity Type Code'].apply(lambda x: activity_types.get(x, None))
X_test['Activity Type Code'] = X_test['Activity Type Code'].apply(lambda x: activity_types.get(x, None))

# %%
price_categories = {
    'Low Fare': 1, 'Other': 2
}

# Convert the 'Price Category Code' column to numbers
X_train['Price Category Code'] = X_train['Price Category Code'].apply(lambda x: price_categories.get(x, None))
X_test['Price Category Code'] = X_test['Price Category Code'].apply(lambda x: price_categories.get(x, None))

# %%
terminals = {
    'Terminal 1': 1, 'International': 2, 'Terminal 3': 3, 'Other': 4, 'Terminal 2': 5
}
X_train['Terminal'] = X_train['Terminal'].apply(lambda x: terminals.get(x, None))
X_test['Terminal'] = X_test['Terminal'].apply(lambda x: terminals.get(x, None))

# %%
boarding_areas = {
    'B': 1, 'G': 2, 'A': 3, 'E': 4, 'C': 5, 'F': 6, 'Other': 7, 'D': 8
}

# Convert the 'Boarding Area' column to numbers
X_train['Boarding Area'] = X_train['Boarding Area'].apply(lambda x: boarding_areas.get(x, None))
X_test['Boarding Area'] = X_test['Boarding Area'].apply(lambda x: boarding_areas.get(x, None))

# %%
geo_summary_mapping = {
    'Domestic': 1,
    'International': 2
}
X_train['GEO Summary'] = X_train['GEO Summary'].apply(lambda x: geo_summary_mapping.get(x, None))
X_test['GEO Summary'] = X_test['GEO Summary'].apply(lambda x: geo_summary_mapping.get(x, None))
y_train['GEO Summary'] = y_train['GEO Summary'].apply(lambda x: geo_summary_mapping.get(x, None))
y_test['GEO Summary'] = y_test['GEO Summary'].apply(lambda x: geo_summary_mapping.get(x, None))

# %%
print(X_train)
# Out:
#        Operating Airline IATA Code  Published Airline  \
# 1154                           7.0                7.0
# 10497                         24.0               21.0
# 7926                           7.0                7.0
# 6350                          26.0               23.0
# 14877                         52.0               47.0
# ...                            ...                ...
# 11798                         38.0               34.0
# 13896                         52.0               47.0
# 6637                          39.0               35.0
# 2575                          27.0               24.0
# 7336                          38.0               31.0
#
#        Published Airline IATA Code  GEO Summary  GEO Region  \
# 1154                           7.0            2           6
# 10497                         24.0            2           3
# 7926                           7.0            2           6
# 6350                          26.0            2           3
# ...

# %%
X_train= X_train.apply(lambda row: row.fillna(row.mean()), axis=1)
X_test= X_test.apply(lambda row: row.fillna(row.mean()), axis=1)
y_train= y_train.apply(lambda row: row.fillna(row.mean()), axis=1)
y_test= y_test.apply(lambda row: row.fillna(row.mean()), axis=1)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
print(f"intercept: {lr_model.intercept_}")
print(f"coefficients: {lr_model.coef_}")
# Out:
# intercept: [3.28626015e-14]
# coefficients: [[-3.24988134e-16  1.31405303e-16  3.22945711e-16  1.00000000e+00
#   -7.58592927e-16 -5.42124689e-15  2.12288378e-14 -1.18673106e-14
#    8.40556954e-16 -1.42301535e-19]]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
dtr_model = DecisionTreeRegressor()
dtr_model.fit(X_train, y_train)
y_pred = dtr_model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f"R-squared score: {r2}")
print(np.sqrt(mean_squared_error(y_test,y_pred)))
dt=mean_squared_error(y_test,y_pred )
print(mean_squared_error(y_test,y_pred ))
print(mean_absolute_error(y_test,y_pred ))
# Out:
# R-squared score: 1.0
# 0.0
# 0.0
# 0.0

# %%
import numpy as np
from sklearn import linear_model
from sklearn.metrics import mean_squared_error,mean_absolute_error
reg_all=linear_model.LinearRegression()
reg_all.fit(X_train,y_train)
y_pred=reg_all.predict(X_test)
mse=mean_squared_error(y_test,y_pred)
print("mse:",mse)
mae = mean_absolute_error(y_test,y_pred)
print("mae:",mae)
print("rmse:",np.sqrt(mean_squared_error(y_test,y_pred)))
r2 = r2_score(y_test, y_pred)
print(f"R-squared score: {r2}")
# Out:
# mse: 7.416228016781173e-27
# mae: 3.6536840619394615e-14
# rmse: 8.611752444642828e-14
# R-squared score: 1.0

# %%
from sklearn.neighbors import KNeighborsRegressor
kk=KNeighborsRegressor()
kl=kk.fit(X_train, y_train.values.ravel())

# %%
yp=kl.predict(X_test)
print(yp)
print(y_test)
# Out:
# [1.8 1.4 1.6 ... 1.8 2.  1.6]
#       GEO Summary
# 4287            1
# 9815            2
# 616             2
# 6604            1
# 8126            2
# ...           ...
# 7517            2
# 2886            2
# 7969            2
# 3073            1
# 5773            1
#
# [3002 rows x 1 columns]

# %%
print(np.sqrt(mean_squared_error(y_test,yp)))
knn=mean_squared_error(y_test,yp )
print(mean_squared_error(y_test,yp ))
print(mean_absolute_error(y_test,yp ))
r2 = r2_score(y_test, y_pred)
print(f"R-squared score: {r2}")
# Out:
# 0.0
# 0.0
# 0.0
# R-squared score: 1.0

# %%
from sklearn.ensemble import RandomForestRegressor
rfc = RandomForestRegressor()

# %%
rr=rfc.fit(X_train,y_train.values.ravel())
yp=rr.predict(X_test)
print(yp)
# Out:
# [1. 2. 2. ... 2. 1. 1.]

# %%
print(np.sqrt(mean_squared_error(y_test,yp)))
rf=mean_squared_error(y_test,yp)
print(rf)
print(mean_absolute_error(y_test,yp ))
# Out:
# 0.0
# 0.0
# 0.0

# %%
importance = pd.Series(rf_model.feature_importances_)
importance.index = X_train.columns
importance.sort_values(inplace=True, ascending=False)
importance.head(10).plot.barh(figsize=(18,6))
# Out:
# <Axes: >

# %%
from xgboost import XGBRegressor
from math import sqrt
from sklearn import metrics
regressor = XGBRegressor()
regressor.fit(X_train, y_train)
# prediction on training data
training_data_prediction = regressor.predict(X_train)
mse = mean_squared_error(y_train,training_data_prediction)
xgb=(mse)
print("MSE of Training =",sqrt(xgb))
# R squared Value
r2_train = metrics.r2_score(y_train, training_data_prediction)
# prediction on test data
test_data_prediction = regressor.predict(X_test)
'''mse2 = mean_squared_error(Y_test,training_data_prediction)'''
'''print("MSE of test =",mse2)'''
# R squared Value
r2_test = metrics.r2_score(y_test, test_data_prediction)
print('R Squared value = ', r2_train)
print('R Squared value = ', r2_test)
# Out:
# 5.947860849776618e-11
# MSE of Training = 7.712237580479881e-06
# R Squared value =  0.9999999997485738
# R Squared value =  0.9999999997486065

# %%
importance = pd.Series(regressor.feature_importances_)
importance.index = X_train.columns
importance.sort_values(inplace=True, ascending=False)
importance.head(10).plot.barh(figsize=(18,6))
# Out:
# <Axes: >

# %%
import seaborn as sns
models = pd.DataFrame({
    'Model':['XGBRegressor','Linear Regression', 'KNeighbours', 'Decision Trees', 'Random Forest'],
    'Error_score' :[xgb, mse, knn, dt, rf]
})
models
sns.barplot(x='Error_score', y='Model', data=models)

models.sort_values(by='Error_score', ascending=False)
# Out:
#                Model   Error_score
# 2        KNeighbours  1.530846e-01
# 0       XGBRegressor  5.947861e-11
# 1  Linear Regression  5.947861e-11
# 3     Decision Trees  0.000000e+00
# 4      Random Forest  0.000000e+00
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_44, *['Error_score'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# ...
